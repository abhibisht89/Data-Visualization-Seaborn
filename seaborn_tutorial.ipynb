# %% [markdown]
# # Seaborn
#
#
# Seaborn is a library for making attractive and informative statistical graphics in Python. It is built on top of matplotlib and tightly integrated with the PyData stack, including support for numpy and pandas data structures and statistical routines from scipy and statsmodels.

# %%
import pandas as pd
import math
import numpy as np
from scipy import stats, integrate
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
data_file=r'Data/Existing Base.csv'
# data set taken here is 'Existing Base'

eb=pd.read_csv(data_file)

# %%
eb=eb.head(100) # for the sake of simplicity i have taken only first 100 observations, 
                #you can go ahead and can consider the whole dataset

# %%
eb
# Out:
#     REF_NO children age_band                status         occupation  \
# 0        1     Zero    51-55               Partner      Manual Worker
# 1        2     Zero    55-60  Single/Never Married            Retired
# 2        3     Zero    26-30  Single/Never Married       Professional
# 3        5     Zero    18-21  Single/Never Married       Professional
# 4        6     Zero    45-50               Partner   Business Manager
# 5        7     Zero    55-60               Partner  Secretarial/Admin
# 6        8     Zero    45-50               Partner       Professional
# 7        9        1    36-40               Partner       Professional
# 8       10     Zero    36-40  Single/Never Married  Secretarial/Admin
# 9       11        2    36-40               Partner       Professional
# 10      13     Zero    61-65               Partner            Retired
# 11      14     Zero    45-50               Partner   Business Manager
# 12      15     Zero    51-55               Widowed       Professional
# 13      16     Zero    31-35  Single/Never Married      Manual Worker
# 14      17        1    31-35               Partner  Secretarial/Admin
# 15      18     Zero    26-30               Partner            Unknown
# 16      19     Zero    41-45               Partner  Secretarial/Admin
# 17      20     Zero    41-45    Divorced/Separated       Professional
# 18      21        1    41-45               Partner  Secretarial/Admin
# 19      23     Zero    41-45    Divorced/Separated  Secretarial/Admin
# 20      26     Zero    26-30               Partner       Professional
# 21      27        2    31-35               Partner   Business Manager
# 22      28     Zero      71+               Partner            Retired
# 23      29        3    36-40               Partner   Business Manager
# 24      30        1    26-30               Partner  Secretarial/Admin
# 25      31        1    22-25               Partner  Secretarial/Admin
# 26      33        1    45-50               Partner      Manual Worker
# 27      34     Zero    22-25               Partner       Professional
# 28      35     Zero    65-70               Widowed            Retired
# 29      36        2    36-40               Partner  Secretarial/Admin
# ..     ...      ...      ...                   ...                ...
# 70      79        1    45-50               Partner       Professional
# 71      80     Zero    26-30               Partner   Business Manager
# 72      81     Zero    51-55               Partner       Professional
# 73      82     Zero    55-60               Partner            Retired
# 74      83        2    36-40               Partner            Unknown
# 75      84        2    31-35               Partner  Secretarial/Admin
# 76      85        1    36-40               Partner          Housewife
# 77      87     Zero    41-45  Single/Never Married  Secretarial/Admin
# 78      88        3    31-35               Partner          Housewife
# 79      89     Zero    45-50               Partner       Professional
# 80      90        1    36-40               Partner  Secretarial/Admin
# 81      91        1    41-45    Divorced/Separated  Secretarial/Admin
# 82      92        1    36-40               Partner       Professional
# 83      94     Zero    45-50               Partner              Other
# 84      96     Zero    55-60               Partner  Secretarial/Admin
# 85      97     Zero    55-60               Partner          Housewife
# 86      98     Zero    26-30               Partner      Manual Worker
# 87      99     Zero    26-30               Partner   Business Manager
# 88     100     Zero    22-25               Partner   Business Manager
# 89     101        3    41-45               Widowed   Business Manager
# 90     102     Zero    36-40               Partner   Business Manager
# 91     103     Zero    22-25               Partner       Professional
# 92     104     Zero    22-25  Single/Never Married  Secretarial/Admin
# 93     106     Zero    65-70               Partner          Housewife
# 94     107     Zero    65-70               Partner          Housewife
# 95     108     Zero    65-70               Partner            Retired
# 96     109     Zero    31-35  Single/Never Married  Secretarial/Admin
# 97     110     Zero    55-60               Partner       Professional
# 98     111        1    26-30               Partner       Professional
# 99     112     Zero    55-60               Partner            Retired
#
#    occupation_partner           home_status      family_income self_employed  \
# 0   Secretarial/Admin              Own Home  <17,500, >=15,000            No
# 1             Retired              Own Home  <27,500, >=25,000            No
# 2               Other              Own Home  <30,000, >=27,500           Yes
# 3       Manual Worker              Own Home  <15,000, >=12,500            No
# 4             Unknown              Own Home  <30,000, >=27,500            No
# 5       Manual Worker              Own Home  <17,500, >=15,000            No
# 6       Manual Worker              Own Home           >=35,000            No
# 7        Professional              Own Home           >=35,000            No
# 8             Unknown              Own Home  <17,500, >=15,000            No
# 9        Professional              Own Home           >=35,000            No
# 10            Retired              Own Home  <12,500, >=10,000            No
# 11       Professional              Own Home           >=35,000            No
# 12            Unknown              Own Home           >=35,000            No
# 13  Secretarial/Admin              Own Home  <25,000, >=22,500            No
# 14   Business Manager              Own Home  <30,000, >=27,500            No
# 15       Professional              Own Home           >=35,000           Yes
# 16            Unknown              Own Home           >=35,000            No
# 17            Unknown              Own Home  <25,000, >=22,500            No
# 18      Manual Worker              Own Home  <12,500, >=10,000            No
# 19            Unknown              Own Home  <10,000, >= 8,000            No
# 20       Professional              Own Home           >=35,000            No
# 21   Business Manager              Own Home           >=35,000            No
# 22            Retired              Own Home  <22,500, >=20,000            No
# 23       Professional              Own Home  <27,500, >=25,000            No
# 24   Business Manager              Own Home           >=35,000            No
# 25      Manual Worker              Own Home  <22,500, >=20,000            No
# 26            Unknown              Own Home  <17,500, >=15,000            No
# 27       Professional              Own Home           >=35,000            No
# 28            Unknown              Own Home  <15,000, >=12,500            No
# 29   Business Manager              Own Home           >=35,000            No
# ..                ...                   ...                ...           ...
# 70       Professional              Own Home           >=35,000            No
# 71      Manual Worker              Own Home           >=35,000            No
# 72       Professional              Own Home  <27,500, >=25,000            No
# 73            Retired              Own Home  <10,000, >= 8,000            No
# 74            Unknown              Own Home  < 8,000, >= 4,000           Yes
# 75       Professional              Own Home           >=35,000            No
# 76      Manual Worker              Own Home  <22,500, >=20,000           Yes
# 77            Unknown              Own Home  <15,000, >=12,500            No
# 78       Professional              Own Home  <27,500, >=25,000            No
# 79            Unknown              Own Home  <27,500, >=25,000            No
# 80       Professional              Own Home  <27,500, >=25,000            No
# 81            Unknown              Own Home  <22,500, >=20,000            No
# 82   Business Manager              Own Home  <30,000, >=27,500            No
# 83              Other              Own Home            < 4,000            No
# 84      Manual Worker              Own Home  <27,500, >=25,000            No
# 85       Professional              Own Home           >=35,000            No
# 86      Manual Worker              Own Home           >=35,000            No
# 87   Business Manager              Own Home           >=35,000            No
# 88       Professional              Own Home           >=35,000           Yes
# 89            Unknown              Own Home  <15,000, >=12,500            No
# 90       Professional        Rent Privately           >=35,000            No
# 91      Manual Worker              Own Home           >=35,000            No
# 92            Unknown              Own Home  <15,000, >=12,500            No
# 93            Retired              Own Home  <12,500, >=10,000            No
# 94            Retired              Own Home  <20,000, >=17,500            No
# 95            Retired              Own Home  <20,000, >=17,500            No
# 96            Retired  Live in Parental Hom  <15,000, >=12,500            No
# 97          Housewife              Own Home           >=35,000           Yes
# 98       Professional        Rent Privately           >=35,000            No
# 99            Retired              Own Home  < 8,000, >= 4,000            No
#
#    self_employed_partner        ...          Investment Tax Saving Bond  \
# 0                     No        ...                               19.99
# 1                     No        ...                                0.00
# 2                     No        ...                                0.00
# 3                     No        ...                                0.00
# 4                     No        ...                                0.00
# 5                    Yes        ...                                0.00
# 6                     No        ...                                0.00
# 7                     No        ...                               41.71
# 8                     No        ...                               12.48
# 9                     No        ...                                0.00
# 10                    No        ...                                0.00
# 11                    No        ...                                0.00
# 12                    No        ...                                0.00
# 13                    No        ...                                2.00
# 14                    No        ...                                7.49
# 15                    No        ...                                0.00
# 16                   Yes        ...                                0.00
# 17                    No        ...                                0.00
# 18                    No        ...                               12.49
# 19                    No        ...                                0.00
# 20                    No        ...                                0.00
# 21                    No        ...                                0.00
# 22                    No        ...                                9.99
# 23                   Yes        ...                               25.61
# 24                    No        ...                                0.00
# 25                   Yes        ...                               19.49
# 26                   Yes        ...                                0.00
# 27                   Yes        ...                                5.99
# 28                    No        ...                                9.99
# 29                    No        ...                                7.97
# ..                   ...        ...                                 ...
# 70                   Yes        ...                               10.98
# 71                    No        ...                               15.98
# 72                    No        ...                               43.92
# 73                    No        ...                                0.00
# 74                   Yes        ...                                0.00
# 75                    No        ...                                0.00
# 76                    No        ...                                0.00
# 77                    No        ...                                0.00
# 78                    No        ...                                0.00
# 79                   Yes        ...                               28.49
# 80                   Yes        ...                                0.00
# 81                    No        ...                                0.00
# 82                    No        ...                                8.47
# 83                    No        ...                                0.00
# 84                    No        ...                                0.00
# 85                    No        ...                                0.00
# 86                    No        ...                                0.00
# 87                    No        ...                               19.44
# 88                    No        ...                                0.00
# 89                    No        ...                                0.00
# 90                    No        ...                                0.00
# 91                    No        ...                                0.00
# 92                    No        ...                                0.00
# 93                    No        ...                               29.49
# 94                    No        ...                                0.00
# 95                    No        ...                                4.99
# 96                    No        ...                                0.00
# 97                    No        ...                                0.00
# 98                    No        ...                                0.00
# 99                    No        ...                                0.00
#
#    Home Loan Online Purchase Amount Revenue Grid  gender            region  \
# 0       0.00                   0.00            1  Female             Wales
# 1       0.00                   0.00            2  Female        North West
# 2       3.49                   0.00            2    Male             North
# 3       0.00                   0.00            2  Female     West Midlands
# 4      45.91                  25.98            2  Female          Scotland
# 5       0.00                   0.00            2  Female       East Anglia
# 6       0.00                   0.00            2  Female     West Midlands
# 7      35.41                  11.99            2  Female          Scotland
# 8       7.21                   8.99            2    Male        South East
# 9      10.49                   7.98            2  Female        North West
# 10      5.99                   0.00            2  Female             Wales
# 11      9.99                   0.00            2  Female             Wales
# 12      4.48                  12.98            2  Female        North West
# 13      0.00                   0.00            2    Male        South West
# 14     18.46                  13.98            2  Female     West Midlands
# 15     39.96                   0.00            2  Female          Scotland
# 16      0.00                   0.00            2  Female     West Midlands
# 17      0.00                  27.99            2  Female     West Midlands
# 18     21.46                   0.00            2  Female     West Midlands
# 19      0.00                  16.99            2  Female        South West
# 20      0.00                   0.00            2  Female     East Midlands
# 21      0.00                   0.00            2  Female        North West
# 22      0.00                   0.00            2  Female        South West
# 23     31.43                  45.98            2    Male          Scotland
# 24      0.00                   0.00            2  Female           Unknown
# 25     20.76                   0.00            2  Female        South East
# 26      0.00                   0.00            2    Male     East Midlands
# 27      8.69                  24.95            2  Female        South West
# 28     11.47                   0.00            2  Female          Scotland
# 29     23.96                  15.96            2  Female           Unknown
# ..       ...                    ...          ...     ...               ...
# 70      0.00                   0.00            2    Male        North West
# 71      5.73                   0.00            2  Female     East Midlands
# 72      9.49                  45.95            2    Male        South East
# 73      9.98                  25.48            2  Female          Scotland
# 74      0.00                   0.00            2  Female     West Midlands
# 75      0.00                   0.00            2  Female     West Midlands
# 76      0.00                   0.00            2  Female        South East
# 77     45.39                   0.00            2  Female          Scotland
# 78      0.00                   0.00            2  Female     West Midlands
# 79      2.98                   2.49            1  Female           Unknown
# 80      9.99                  78.96            1  Female        South East
# 81      0.00                   0.00            2  Female        South East
# 82      0.00                   0.00            1  Female             Wales
# 83     12.46                   0.00            2  Female  Northern Ireland
# 84     23.45                 215.42            1  Female       East Anglia
# 85      0.00                   0.00            2  Female             North
# 86     13.97                   0.00            2    Male     West Midlands
# 87      0.00                  33.95            2    Male        South East
# 88      0.00                   0.00            2  Female        South East
# 89      0.00                   0.00            2  Female     West Midlands
# 90      0.00                   0.05            2  Female          Scotland
# 91      0.00                   0.00            2  Female          Scotland
# 92      0.00                   0.00            2  Female       East Anglia
# 93      0.00                  67.98            1  Female          Scotland
# 94      0.00                   0.00            2  Female        South East
# 95      0.00                   0.00            2    Male        South East
# 96      1.99                   0.00            2  Female          Scotland
# 97      0.00                   0.00            2    Male        North West
# 98      0.00                   0.00            2    Male        South East
# 99      0.00                   0.00            2    Male             Wales
#
#     Investment in Commudity  Investment in Equity  Investment in Derivative  \
# 0                     74.67                 18.66                     32.32
# 1                     20.19                  0.00                      4.33
# 2                     98.06                 31.07                     80.96
# 3                      4.10                 14.15                     17.57
# 4                     70.16                 55.86                     80.44
# 5                     51.08                 14.83                     36.49
# 6                     33.27                 18.90                     25.48
# 7                     48.67                 60.23                     63.58
# 8                     25.29                 61.65                     63.11
# 9                     64.87                 13.74                     41.72
# 10                     5.00                  1.00                      0.00
# 11                    42.29                 20.58                     34.32
# 12                    70.84                 27.56                     65.52
# 13                    79.87                 20.16                     42.98
# 14                    69.68                 19.48                     27.07
# 15                    63.87                 36.64                     59.96
# 16                    32.78                 34.09                     51.50
# 17                    69.78                 31.57                     48.90
# 18                    39.48                 38.63                     62.04
# 19                    64.57                 45.38                     78.53
# 20                    15.20                  5.08                     17.74
# 21                     4.20                  0.00                      3.50
# 22                    75.26                 56.70                     80.93
# 23                    90.23                 51.42                     71.83
# 24                    54.37                 22.57                     58.22
# 25                    16.59                 20.53                     23.73
# 26                    49.68                 18.41                     29.06
# 27                    13.49                 18.18                     23.82
# 28                    32.98                  3.58                     13.66
# 29                   138.91                 41.61                     63.25
# ..                      ...                   ...                       ...
# 70                    25.38                 15.07                     22.89
# 71                     2.80                  5.62                      6.99
# 72                     5.20                 61.17                     51.93
# 73                    23.49                 32.63                     38.30
# 74                     0.00                  0.00                      0.00
# 75                    70.96                  0.00                     17.57
# 76                    40.28                 15.99                     23.15
# 77                     4.60                 12.90                      9.16
# 78                     2.40                  0.50                      2.50
# 79                    94.51                  8.91                     45.60
# 80                    31.29                 32.73                     25.40
# 81                     0.00                  2.00                      2.00
# 82                    63.37                 30.89                     42.79
# 83                    79.26                 59.95                     70.78
# 84                   103.46                 81.34                     68.93
# 85                    30.88                 17.16                     28.57
# 86                    48.48                 20.32                     41.90
# 87                    49.98                 16.73                     17.23
# 88                     5.20                 13.99                     13.99
# 89                    11.90                  0.00                      9.91
# 90                    17.18                  3.54                      5.53
# 91                     9.20                  0.00                      0.00
# 92                     4.00                  0.00                      0.00
# 93                    12.30                 18.16                      6.83
# 94                     0.00                  0.00                      0.00
# 95                    77.66                 22.23                     61.21
# 96                    48.57                 13.90                     32.63
# 97                     3.39                  0.00                      2.83
# 98                     6.60                  3.50                      9.00
# 99                    22.79                  6.00                     19.24
#
#     Portfolio Balance
# 0               89.43
# 1               22.78
# 2              171.78
# 3              -41.70
# 4              235.02
# 5               72.30
# 6              115.28
# 7              162.40
# 8              105.20
# 9               93.09
# 10             -18.84
# 11             129.71
# 12             175.41
# 13              77.14
# 14              78.41
# 15             115.89
# 16             129.15
# 17             150.56
# 18             134.44
# 19             207.07
# 20              27.95
# 21              -0.20
# 22             144.84
# 23             181.10
# 24             130.59
# 25              48.80
# 26              82.90
# 27             103.29
# 28              13.55
# 29             193.58
# ..                ...
# 70              85.20
# 71              25.87
# 72             147.88
# 73              70.35
# 74              22.82
# 75             105.33
# 76              84.37
# 77             -12.61
# 78              -8.72
# 79             135.12
# 80              91.73
# 81              15.55
# 82             111.15
# 83             183.71
# 84             271.00
# 85             107.37
# 86              48.40
# 87             100.83
# 88              30.89
# 89              22.43
# 90              38.28
# 91              61.00
# 92               4.98
# 93              29.02
# 94             -11.62
# 95             157.17
# 96             112.12
# 97              10.92
# 98              17.08
# 99              60.94
#
# [100 rows x 32 columns]

# %%
eb.describe()
# Out:
#            REF_NO  year_last_moved  Average Credit Card Transaction  \
# count  100.000000       100.000000                       100.000000
# mean    57.160000      1986.150000                        23.409700
# std     32.137558        14.009647                        50.319681
# min      1.000000      1905.000000                         0.000000
# 25%     30.750000      1983.000000                         0.000000
# 50%     57.500000      1990.000000                         0.000000
# 75%     83.250000      1995.000000                        19.992500
# max    112.000000      1999.000000                       325.390000
#
#        Balance Transfer  Term Deposit  Life Insurance  Medical Insurance  \
# count         100.00000    100.000000      100.000000         100.000000
# mean           51.74660     28.881000       68.584000          20.410800
# std            65.86052     44.430778       69.542901          29.018859
# min             0.00000      0.000000        0.000000           0.000000
# 25%             0.00000      0.000000       11.985000           0.000000
# 50%            29.48500      0.010000       57.965000           9.485000
# 75%            74.98000     39.490000      108.077500          37.950000
# max           378.31000    219.460000      291.370000         143.900000
#
#        Average A/C Balance  Personal Loan  Investment in Mutual Fund  \
# count           100.000000      100.00000                 100.000000
# mean             37.191800       16.55630                  53.965500
# std              55.563812       36.27803                  60.948877
# min               0.000000        0.00000                   0.000000
# 25%               0.000000        0.00000                   0.000000
# 50%              13.975000        0.00000                  35.485000
# 75%              50.862500       14.99000                  87.060000
# max             292.730000      205.80000                 253.270000
#
#        Investment Tax Saving Bond   Home Loan  Online Purchase Amount  \
# count                  100.000000  100.000000               100.00000
# mean                     5.468400    6.336900                23.65500
# std                     10.523839   11.251916                86.00516
# min                      0.000000    0.000000                 0.00000
# 25%                      0.000000    0.000000                 0.00000
# 50%                      0.000000    0.000000                 0.00000
# 75%                      6.365000    8.890000                11.99000
# max                     53.440000   45.910000               659.92000
#
#        Revenue Grid  Investment in Commudity  Investment in Equity  \
# count    100.000000               100.000000            100.000000
# mean       1.900000                38.606800             23.863700
# std        0.301511                31.531487             25.806232
# min        1.000000                 0.000000              0.000000
# 25%        2.000000                13.290000              5.650000
# 50%        2.000000                32.235000             16.360000
# 75%        2.000000                63.395000             32.090000
# max        2.000000               146.610000            134.170000
#
#        Investment in Derivative  Portfolio Balance
# count                100.000000         100.000000
# mean                  33.697300          92.037700
# std                   27.267394          77.073476
# min                    0.000000         -41.700000
# 25%                    9.722500          28.752500
# 50%                   27.650000          83.290000
# 75%                   51.607500         134.357500
# max                  121.400000         313.410000

# %% [markdown]
# # Visualising Numeric Data
#
# Let's take the variable "Portfolio Balance" and see its distribution for which we use distplot() function. This function by default will give histogram and fit a kernel density estimate (KDE).
#
# A histogram represents the distribution of data by forming bins along the range of the data and then drawing bars to show the number of observations that fall in each bin.
#
# The KDE plots the density of observations on one axis with height along the other axis.

# %%
eb_port=eb["Portfolio Balance"]

# %%
eb_port[0:5]
# Out:
# 0     89.43
# 1     22.78
# 2    171.78
# 3    -41.70
# 4    235.02
# Name: Portfolio Balance, dtype: float64

# %%
sns.distplot(eb_port,kde=False) # I have taken kde=False just to obtain histogram

# %%
sns.distplot(eb_port, kde=False, rug=True) #rug plot will draw a small vertical tick at each observation.

# %%
sns.distplot(eb_port,kde=False,norm_hist=True) #density on y axis rather than count

# %%
sns.distplot(eb_port,bins=20, kde=False, rug=True)#binning, number of bins can be chosen explictly

# %%
sns.distplot(eb_port, hist=False)#density plot
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-0939ead79fc9> in <module>()
# ----> 1 sns.distplot(eb_port, hist=False)#density plot
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     222     if kde:
#     223         kde_color = kde_kws.pop("color", color)
# --> 224         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     225         if kde_color != color:
#     226             kde_kws["color"] = kde_color
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     655         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     656                                  gridsize, cut, clip, legend, ax,
# --> 657                                  cumulative=cumulative, **kwargs)
#     658
#     659     return ax
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     271         x, y = _statsmodels_univariate_kde(data, kernel, bw,
#     272                                            gridsize, cut, clip,
# --> 273                                            cumulative=cumulative)
#     274     else:
#     275         # Fall back to scipy if missing statsmodels
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\distributions.py in _statsmodels_univariate_kde(data, kernel, bw, gridsize, cut, clip, cumulative)
#     343     fft = kernel == "gau"
#     344     kde = smnp.KDEUnivariate(data)
# --> 345     kde.fit(kernel, bw, fft, gridsize=gridsize, cut=cut, clip=clip)
#     346     if cumulative:
#     347         grid, y = kde.support, kde.cdf
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in fit(self, kernel, bw, fft, weights, gridsize, adjust, cut, clip)
#     144             density, grid, bw = kdensityfft(endog, kernel=kernel, bw=bw,
#     145                     adjust=adjust, weights=weights, gridsize=gridsize,
# --> 146                     clip=clip, cut=cut)
#     147         else:
#     148             density, grid, bw = kdensity(endog, kernel=kernel, bw=bw,
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     504     zstar = silverman_transform(bw, gridsize, RANGE)*y # 3.49 in Silverman
#     505                                                    # 3.50 w Gaussian kernel
# --> 506     f = revrt(zstar)
#     507     if retgrid:
#     508         return f, grid, bw
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py in revrt(X, m)
#      18     if m is None:
#      19         m = len(X)
# ---> 20     y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
#      21     return np.fft.irfft(y)*m
#      22
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
sns.distplot(eb_port) #both density and histogram plots
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-3c7cd988fb25> in <module>()
# ----> 1 sns.distplot(eb_port) #both density and histogram plots
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     222     if kde:
#     223         kde_color = kde_kws.pop("color", color)
# --> 224         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     225         if kde_color != color:
#     226             kde_kws["color"] = kde_color
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     655         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     656                                  gridsize, cut, clip, legend, ax,
# --> 657                                  cumulative=cumulative, **kwargs)
#     658
#     659     return ax
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     271         x, y = _statsmodels_univariate_kde(data, kernel, bw,
#     272                                            gridsize, cut, clip,
# --> 273                                            cumulative=cumulative)
#     274     else:
#     275         # Fall back to scipy if missing statsmodels
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\distributions.py in _statsmodels_univariate_kde(data, kernel, bw, gridsize, cut, clip, cumulative)
#     343     fft = kernel == "gau"
#     344     kde = smnp.KDEUnivariate(data)
# --> 345     kde.fit(kernel, bw, fft, gridsize=gridsize, cut=cut, clip=clip)
#     346     if cumulative:
#     347         grid, y = kde.support, kde.cdf
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in fit(self, kernel, bw, fft, weights, gridsize, adjust, cut, clip)
#     144             density, grid, bw = kdensityfft(endog, kernel=kernel, bw=bw,
#     145                     adjust=adjust, weights=weights, gridsize=gridsize,
# --> 146                     clip=clip, cut=cut)
#     147         else:
#     148             density, grid, bw = kdensity(endog, kernel=kernel, bw=bw,
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     504     zstar = silverman_transform(bw, gridsize, RANGE)*y # 3.49 in Silverman
#     505                                                    # 3.50 w Gaussian kernel
# --> 506     f = revrt(zstar)
#     507     if retgrid:
#     508         return f, grid, bw
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py in revrt(X, m)
#      18     if m is None:
#      19         m = len(X)
# ---> 20     y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
#      21     return np.fft.irfft(y)*m
#      22
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %% [markdown]
# You can also use kdeplot() to plot density distributions of variables in a single frame

# %%
sns.kdeplot(eb["Portfolio Balance"], shade=True)
sns.kdeplot(eb["Investment in Commudity"], shade=True);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-b10749a335ef> in <module>()
# ----> 1 sns.kdeplot(eb["Portfolio Balance"], shade=True)
#       2 sns.kdeplot(eb["Investment in Commudity"], shade=True);
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     655         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     656                                  gridsize, cut, clip, legend, ax,
# --> 657                                  cumulative=cumulative, **kwargs)
#     658
#     659     return ax
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     271         x, y = _statsmodels_univariate_kde(data, kernel, bw,
#     272                                            gridsize, cut, clip,
# --> 273                                            cumulative=cumulative)
#     274     else:
#     275         # Fall back to scipy if missing statsmodels
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\distributions.py in _statsmodels_univariate_kde(data, kernel, bw, gridsize, cut, clip, cumulative)
#     343     fft = kernel == "gau"
#     344     kde = smnp.KDEUnivariate(data)
# --> 345     kde.fit(kernel, bw, fft, gridsize=gridsize, cut=cut, clip=clip)
#     346     if cumulative:
#     347         grid, y = kde.support, kde.cdf
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in fit(self, kernel, bw, fft, weights, gridsize, adjust, cut, clip)
#     144             density, grid, bw = kdensityfft(endog, kernel=kernel, bw=bw,
#     145                     adjust=adjust, weights=weights, gridsize=gridsize,
# --> 146                     clip=clip, cut=cut)
#     147         else:
#     148             density, grid, bw = kdensity(endog, kernel=kernel, bw=bw,
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     504     zstar = silverman_transform(bw, gridsize, RANGE)*y # 3.49 in Silverman
#     505                                                    # 3.50 w Gaussian kernel
# --> 506     f = revrt(zstar)
#     507     if retgrid:
#     508         return f, grid, bw
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py in revrt(X, m)
#      18     if m is None:
#      19         m = len(X)
# ---> 20     y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
#      21     return np.fft.irfft(y)*m
#      22
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %% [markdown]
# # Plotting Bivariate Distributions
#
#
# Seaborn is useful to visualize a bivariate distribution of two variables. Here we use the jointplot function which shows both the bivariate relationship between two variables along with the univariate distribution of each on separate axes.
#
# Let's consider two variables here "Investment in Commudity" and "Portfolio Balance" and visualize there bivariate distribution.

# %% [markdown]
# ### Scatterplots

# %%
sns.jointplot(x="Investment in Commudity", y="Portfolio Balance", data=eb)
# scatterplot is default kind of plot shown by the jointplot() function

# %% [markdown]
# ### Hexbin plots
#
# This plot shows the counts of observations that fall within hexagonal bins.

# %%
sns.jointplot(x="Investment in Commudity", y="Portfolio Balance", kind="hex",size=5,color="g",data=eb)
# you can always customize attributes size and color

# %% [markdown]
# ### Kernel density estimation
#
# Bivariate distribution can also be visualized using the kernel density estimation.

# %%
sns.jointplot(x="Investment in Commudity", y="Portfolio Balance", kind="kde",size=5,data=eb)
# Out:
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\ma\core.py:6385: MaskedArrayFutureWarning: In the future the default for ma.maximum.reduce will be axis=0, not the current None, to match np.maximum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\ma\core.py:6385: MaskedArrayFutureWarning: In the future the default for ma.minimum.reduce will be axis=0, not the current None, to match np.minimum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-d219098c2bdc> in <module>()
# ----> 1 sns.jointplot(x="Investment in Commudity", y="Portfolio Balance", kind="kde",size=5,data=eb)
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2273         marginal_kws.setdefault("shade", True)
#    2274         marginal_kws.setdefault("color", color)
# -> 2275         grid.plot_marginals(kdeplot, **marginal_kws)
#    2276
#    2277     elif kind.startswith("reg"):
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\axisgrid.py in plot_marginals(self, func, **kwargs)
#    1778         kwargs["vertical"] = False
#    1779         plt.sca(self.ax_marg_x)
# -> 1780         func(self.x, **kwargs)
#    1781
#    1782         kwargs["vertical"] = True
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     655         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     656                                  gridsize, cut, clip, legend, ax,
# --> 657                                  cumulative=cumulative, **kwargs)
#     658
#     659     return ax
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     271         x, y = _statsmodels_univariate_kde(data, kernel, bw,
#     272                                            gridsize, cut, clip,
# --> 273                                            cumulative=cumulative)
#     274     else:
#     275         # Fall back to scipy if missing statsmodels
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\distributions.py in _statsmodels_univariate_kde(data, kernel, bw, gridsize, cut, clip, cumulative)
#     343     fft = kernel == "gau"
#     344     kde = smnp.KDEUnivariate(data)
# --> 345     kde.fit(kernel, bw, fft, gridsize=gridsize, cut=cut, clip=clip)
#     346     if cumulative:
#     347         grid, y = kde.support, kde.cdf
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in fit(self, kernel, bw, fft, weights, gridsize, adjust, cut, clip)
#     144             density, grid, bw = kdensityfft(endog, kernel=kernel, bw=bw,
#     145                     adjust=adjust, weights=weights, gridsize=gridsize,
# --> 146                     clip=clip, cut=cut)
#     147         else:
#     148             density, grid, bw = kdensity(endog, kernel=kernel, bw=bw,
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     504     zstar = silverman_transform(bw, gridsize, RANGE)*y # 3.49 in Silverman
#     505                                                    # 3.50 w Gaussian kernel
# --> 506     f = revrt(zstar)
#     507     if retgrid:
#     508         return f, grid, bw
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py in revrt(X, m)
#      18     if m is None:
#      19         m = len(X)
# ---> 20     y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
#      21     return np.fft.irfft(y)*m
#      22
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
s=sns.jointplot(x="Investment in Commudity", y="Portfolio Balance", kind="kde",size=5,data=eb)
s.plot_joint(plt.scatter, c="r", s=30, linewidth=0.5, marker="*")
s.ax_joint.collections[0].set_alpha(0);
# you can add more layers to it to tweak other aspects of visualization
# Out:
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\ma\core.py:6385: MaskedArrayFutureWarning: In the future the default for ma.maximum.reduce will be axis=0, not the current None, to match np.maximum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\ma\core.py:6385: MaskedArrayFutureWarning: In the future the default for ma.minimum.reduce will be axis=0, not the current None, to match np.minimum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-72fbe22cf76b> in <module>()
# ----> 1 s=sns.jointplot(x="Investment in Commudity", y="Portfolio Balance", kind="kde",size=5,data=eb)
#       2 s.plot_joint(plt.scatter, c="r", s=30, linewidth=0.5, marker="*")
#       3 s.ax_joint.collections[0].set_alpha(0);
#       4 # you can add more layers to it to tweak other aspects of visualization
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2273         marginal_kws.setdefault("shade", True)
#    2274         marginal_kws.setdefault("color", color)
# -> 2275         grid.plot_marginals(kdeplot, **marginal_kws)
#    2276
#    2277     elif kind.startswith("reg"):
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\axisgrid.py in plot_marginals(self, func, **kwargs)
#    1778         kwargs["vertical"] = False
#    1779         plt.sca(self.ax_marg_x)
# -> 1780         func(self.x, **kwargs)
#    1781
#    1782         kwargs["vertical"] = True
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     655         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     656                                  gridsize, cut, clip, legend, ax,
# --> 657                                  cumulative=cumulative, **kwargs)
#     658
#     659     return ax
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     271         x, y = _statsmodels_univariate_kde(data, kernel, bw,
#     272                                            gridsize, cut, clip,
# --> 273                                            cumulative=cumulative)
#     274     else:
#     275         # Fall back to scipy if missing statsmodels
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\seaborn\distributions.py in _statsmodels_univariate_kde(data, kernel, bw, gridsize, cut, clip, cumulative)
#     343     fft = kernel == "gau"
#     344     kde = smnp.KDEUnivariate(data)
# --> 345     kde.fit(kernel, bw, fft, gridsize=gridsize, cut=cut, clip=clip)
#     346     if cumulative:
#     347         grid, y = kde.support, kde.cdf
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in fit(self, kernel, bw, fft, weights, gridsize, adjust, cut, clip)
#     144             density, grid, bw = kdensityfft(endog, kernel=kernel, bw=bw,
#     145                     adjust=adjust, weights=weights, gridsize=gridsize,
# --> 146                     clip=clip, cut=cut)
#     147         else:
#     148             density, grid, bw = kdensity(endog, kernel=kernel, bw=bw,
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     504     zstar = silverman_transform(bw, gridsize, RANGE)*y # 3.49 in Silverman
#     505                                                    # 3.50 w Gaussian kernel
# --> 506     f = revrt(zstar)
#     507     if retgrid:
#     508         return f, grid, bw
#
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py in revrt(X, m)
#      18     if m is None:
#      19         m = len(X)
# ---> 20     y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
#      21     return np.fft.irfft(y)*m
#      22
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %% [markdown]
# ### Functions to draw linear regression models
#
# Now to visualize a linear relationship between two variables we use the function lmplot().

# %%
sns.lmplot('Investment in Commudity', 'Portfolio Balance', 
           data=eb,palette="Set1",
           fit_reg=False)

# fit_reg=False will give only the scatterplot of both the variables

# %%
sns.lmplot('Investment in Commudity', 'Portfolio Balance', 
           data=eb,palette="Set1")
# lmplot function by default gives a regression line (linear relationship) between the two variables

# %%
sns.lmplot('Investment in Commudity', 'Portfolio Balance', 
           data=eb, 
           order=3)

# setting order here will give polynomial relationship between two variables

# %%
sns.lmplot('Investment in Commudity', 'Portfolio Balance', hue="gender",data=eb,fit_reg=False)
plt.title("myplot", fontname='Ubuntu', fontsize=14,
            fontstyle='italic', fontweight='bold')

# shows how does the relationship between the two variables change as a function of a third variable,
# here the third variable is "gender"

#Note: You can add lable to this such as title
# Out:
# C:\Users\abhi\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1288: UserWarning: findfont: Font family ['Ubuntu'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# To add another variable,
# you can draw multiple “facets” which each level of the variable appearing in the rows or columns of the grid.

# %%
sns.lmplot('Investment in Commudity', 'Portfolio Balance', hue="gender",col="status",data=eb,fit_reg=False,size=3)

# %%
sns.lmplot('Investment in Commudity', 'Portfolio Balance', hue="gender",col="status",row="self_employed",
            data=eb,fit_reg=False,size=4)

# %% [markdown]
# # Visualising categorical data
#
# From above plots we have seen bivariate relationship between two continuous variabes, but what if one of the main variables you are interested in is categorical? In this case, the scatterplot and regression model approach won’t work.
#
# So we are going to look into different plots in order to visualize categorical variables.

# %% [markdown]
# ### Categorical Scatterplots
#
# We will use the function stripplot(), which generalizes a scatterplot to the case where one of the variables is categorical

# %%
sns.stripplot(x='status', y="Portfolio Balance", data=eb,jitter=True)
# jitter is used to avoid any overlap between the data points

# %% [markdown]
# Or you can use swarmplot(),which positions each scatterplot point on the categorical axis such that it avoids overlapping points

# %%
sns.swarmplot(x='status', y="Portfolio Balance", data=eb)

# %% [markdown]
# You can also add another categorical variable using hue parameter

# %%
sns.swarmplot(x='status', y="Portfolio Balance",hue="gender", data=eb)

# %% [markdown]
# ### Distributions of observations within categories
#
# **boxplot():** shows the three quartile values of the distribution along with extreme values. The “whiskers” extend to points that lie within 1.5 IQRs of the lower and upper quartile and the points outside these are considered as outliers.

# %%
sns.boxplot(x='status', y="Portfolio Balance", data=eb)

# %% [markdown]
# **violinplot():** combines a boxplot with the kernel density estimation, the quartile and whikser values from the boxplot are shown inside the violin

# %%
sns.violinplot(y="Portfolio Balance", x="children", data=eb)

# %% [markdown]
# You can also add another categorical variable using hue parameter

# %%
sns.violinplot(x="Portfolio Balance", y="children",hue="status", data=eb)

# %% [markdown]
# # Statistical estimation within categories
#
# **countplot():** counts number of observations in each category.

# %%
sns.countplot(x="age_band", data=eb,palette="Greens_d")
# gives the count of each age_band

# %%
sns.countplot(x="age_band", data=eb,hue="children",palette="Greens_d")
# adding another categorical variable

# %% [markdown]
# **barplot():** operates on a full dataset and shows an arbitrary estimate, using the mean by default.

# %%
sns.barplot(x="status", y="Investment in Commudity",hue="children",data=eb)

# %%
sns.barplot(x="Investment in Commudity", y="status",hue="gender",data=eb)

# %% [markdown]
# # Heatmap
#
#
# Load the example flights dataset and convert to long-form

# %%
sns.set()
flights = sns.load_dataset("flights")
flights.dropna().head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights_long = flights.pivot("month", "year", "passengers")
flights_long
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# December    118   140   166   194   201   229   278   306   336   337   405
#
# year       1960
# month
# January     417
# February    391
# March       419
# April       461
# May         472
# June        535
# July        622
# August      606
# September   508
# October     461
# November    390
# December    432

# %% [markdown]
# heatmap() function gives a good color mapping of the data.

# %%
sns.heatmap(flights_long, annot=True, fmt="d", linewidths=.5)
